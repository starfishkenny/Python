# %% [markdown]
# ### 구글 코랩 사양

# %%
  # 플랫폼
  import platform
  platform.platform()
# Out:
# 'Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic'

# %%
# 운영체제
# !cat /etc/issue.net
# Out:
# Ubuntu 18.04.5 LTS

# %%
# CPU 사양
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %%
# 메모리 사양
# !cat /proc/meminfo
# Out:
# MemTotal:       13302928 kB
# MemFree:        10284336 kB
# MemAvailable:   12468616 kB
# Buffers:          139380 kB
# Cached:          2161284 kB
# SwapCached:            0 kB
# Active:          1102224 kB
# Inactive:        1668500 kB
# Active(anon):     419756 kB
# Inactive(anon):      432 kB
# Active(file):     682468 kB
# Inactive(file):  1668068 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:              1012 kB
# Writeback:             0 kB
# AnonPages:        470172 kB
# Mapped:           290504 kB
# Shmem:              1148 kB
# KReclaimable:     150436 kB
# Slab:             196508 kB
# SReclaimable:     150436 kB
# SUnreclaim:        46072 kB
# KernelStack:        5712 kB
# PageTables:         6764 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6651464 kB
# Committed_AS:    3695756 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:        8216 kB
# VmallocChunk:          0 kB
# Percpu:             1400 kB
# AnonHugePages:      2048 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# FileHugePages:         0 kB
# FilePmdMapped:         0 kB
# CmaTotal:              0 kB
# CmaFree:               0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# Hugetlb:               0 kB
# DirectMap4k:      107328 kB
# DirectMap2M:     6180864 kB
# DirectMap1G:     9437184 kB

# %%
# 디스크 사양
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   37G   71G  35% /
# tmpfs            64M     0   64M   0% /dev
# tmpfs           6.4G     0  6.4G   0% /sys/fs/cgroup
# shm             5.9G     0  5.9G   0% /dev/shm
# tmpfs           6.4G   36K  6.4G   1% /var/colab
# /dev/sda1        76G   42G   35G  55% /etc/hosts
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware
# drive            15G  2.5G   13G  17% /content/drive

# %%
# 파이썬 버전
# !python --version
# Out:
# Python 3.7.11

# %% [markdown]
# ### 코랩 런타임
#
# * GPU 및 TPU 사용 가능

# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %% [markdown]
# ### 파일 저장 및 다운로드/업로드

# %%
# %%writefile test.txt
# text
# Out:
# Overwriting test.txt

# %%
# !cat test.txt
# Out:
# text

# %%
from google.colab import files
files.download('test.txt')

# %%
upload = files.upload()
# Out:
#      <input type="file" id="files-52125da0-74ae-46fc-82cb-0bf29d5dbf17" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-52125da0-74ae-46fc-82cb-0bf29d5dbf17">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
# !ls

# %% [markdown]
# ### 구글 드라이브 연동

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !ls /content/drive

# %% [markdown]
# ### Jupyter Notebook

# %%
# ?로 설명 보기
max?

# %%
li = ['one', 'two', 'three']
li?

# %%
li.count?

# %%
def power(b, n):
    """b의 n승을 반환"""
    return pow(b,n)

# %%
power(2,4)

# %%
power?

# %%
power?? # 소스까지 나타냄

# %% [markdown]
# ### 탭 자동완성

# %%
li = [['one, two', 'three']]
li.append

# %% [markdown]
# ### 와일드카드 매칭
#
# * 단어의 중간이나 마지막 글자로 매칭하여 객체나 속성 찾기

# %%
*Error?

# %%
str.*index*?

# %% [markdown]
# ### 매직 명령어
#
# * Jupyter Notebook 환경에서 파이썬 파일 저장 및 실행

# %%
# %%writefile test.py
print('Hello Colab')

# %%
# %run test.py

# %%
# 코드 실행 시간 측정
# %%timeit?

# %%
# 한 줄 코드
# %timeit li = [n**n for n in range(10000)]

# %%
# 여러 줄 코드
# %%timeit 
li = []
for n in range(10000):
    li.append(n**n)

# %% [markdown]
# ### 입력과 출력 이력
#
# * In과 Out 객체를 통해 이전 명령어와 명령어의 출력 결과 보기

# %%
In

# %%
In[27]

# %%
Out

# %%
Out[1]

# %%
print("In[14]: " + In[14] + "\nOut[35]: " + Out[35])

# %%
# _를 이용한 이전 출력값 출력하기
print(_)

# %%
print(__)

# %%
print(___)

# %%
_19

# %%
# %history를 이용한 입력 이력 살펴보기
# %history -n 1-7

# %%
# rerun을 이용해 이전 입력 이력 다시 실행
# %rerun

# %% [markdown]
# ### 셸 명령어

# %%
# ls: 디렉토리 리스트 보기
# !ls

# %%
# pwd: 현재경로
# !pwd

# %%
# cd: 디렉토리 변경
# !cd sample_data/ && ls

# %%
# %cd: 지속적인 디렉토리 변경
# %cd sample_data/

# %%
# echo: 화면출력
# !echo "Shell"

# %%
# mkdir: 디렉토리 생성
# !mkdir tmp

# %%
# !ls

# %%
# !cat README.md

# %%
# cp: 디렉토리/파일 복사
# !cp README.md tmp/

# %%
# !ls tmp/

# %%
#rm: 디렉토리/파일 삭제
# !rm -r tmp

# %%
# !ls

# %% [markdown]
# ### 마크다운 (Markdown)

# %% [markdown]
# ### 제목
#
# # Heading1
# ## Heading2
# ### Heading3
# #### Heading4
# ##### Heading5
# ###### Heading 6

# %% [markdown]
# ### 목록
#
# 1. 첫째
#
# 2. 둘째
#
# 3. 셋째
#
# * 1단계
#   + 2단계
#     - 3단계

# %% [markdown]
# ### 글씨체
#
# **bold**
# __bold__
# *italic*
# _italic_
# ~~strike~~
# <u>underbar<u>

# %% [markdown]
# > 인용1
# >>인용2
# >>> 인용3

# %% [markdown]
# ### 링크
#
# [Google](https://www.google.com)

# %% [markdown]
# ### 이미지
#
# ![이미지](https://www.google.com/images/branding/googlelogo/1x/googlelogo_color_272x92dp.png)

# %% [markdown]
# ### 수평선
# ---

# %% [markdown]
# |C1|C2|C3|
# |:---|---:|:---:|
# |nate & dogg|2pac & shakur|yessir|

# %% [markdown]
# ### 코드
#
# `inline code`
#
# ```
# block code
# ```
#
# ```python
# def power(b,n):
#     return pow(b,n)
# ```
